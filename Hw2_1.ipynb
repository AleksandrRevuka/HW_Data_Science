# %% [markdown]
# <a href="https://colab.research.google.com/github/AleksandrRevuka/HW_Data_Science/blob/main/Hw2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_html("https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B8",
                    attrs={"class": "wikitable collapsible collapsed"})
birth_in_regions = data[3]

for col in birth_in_regions.columns[1:]:
    birth_in_regions[col] = pd.to_numeric(birth_in_regions[col], errors='coerce') * 0.1

birth_in_regions
# Out:
#                Регіон  1950  1960  1970  1990  2000  2012  2014  2019
# 0                Крим  23.0  20.6  16.0  13.0   7.3  12.6   NaN   NaN
# 1           Вінницька  22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# 2           Волинська  24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# 3    Дніпропетровська  20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# 4            Донецька  27.1  21.4  14.0  10.9   6.1   9.8   8.2   NaN
# 5         Житомирська  26.1  22.3  15.9  12.9   8.9  12.2  12.0   7.9
# 6        Закарпатська  31.4  27.3  20.7  16.8  11.5  15.1  14.6  10.4
# 7          Запорізька  21.9  19.7  15.0  12.4   7.1  10.6  10.6   6.8
# 8   Івано-Франківська  24.3  24.8  18.2  15.5  10.3  12.4  12.2   8.8
# 9            Київська  20.4  18.9  15.6  12.3   7.3  12.2  12.1   8.0
# 10     Кіровоградська  21.6  17.1  14.5  12.6   7.9  11.0  10.8   6.8
# 11          Луганська  26.2  23.5  14.4  11.6   6.2   9.6   5.1   NaN
# ...

# %% [markdown]
# Вивести перші рядки таблиці за допомогою методу head

# %%
print(birth_in_regions.head())
# Out:
#              Регіон  1950  1960  1970  1990  2000  2012  2014  2019
# 0              Крим  23.0  20.6  16.0  13.0   7.3  12.6   NaN   NaN
# 1         Вінницька  22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# 2         Волинська  24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# 3  Дніпропетровська  20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# 4          Донецька  27.1  21.4  14.0  10.9   6.1   9.8   8.2   NaN

# %% [markdown]
# Визначте кількість рядків та стовпців у датафреймі (атрибут shape)

# %%
rows, colums = birth_in_regions.shape

print(f"rows: {rows}\ncolums: {colums}")
# Out:
# rows: 28
# colums: 9

# %% [markdown]
# Замініть у таблиці значення "—" на значення NaN

# %%
import numpy as np


birth_in_regions.replace("—", np.nan, inplace=True)

print(birth_in_regions)
# Out:
#                Регіон  1950  1960  1970  1990  2000  2012  2014  2019
# 0                Крим  23.0  20.6  16.0  13.0   7.3  12.6   NaN   NaN
# 1           Вінницька  22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# 2           Волинська  24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# 3    Дніпропетровська  20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# 4            Донецька  27.1  21.4  14.0  10.9   6.1   9.8   8.2   NaN
# 5         Житомирська  26.1  22.3  15.9  12.9   8.9  12.2  12.0   7.9
# 6        Закарпатська  31.4  27.3  20.7  16.8  11.5  15.1  14.6  10.4
# 7          Запорізька  21.9  19.7  15.0  12.4   7.1  10.6  10.6   6.8
# 8   Івано-Франківська  24.3  24.8  18.2  15.5  10.3  12.4  12.2   8.8
# 9            Київська  20.4  18.9  15.6  12.3   7.3  12.2  12.1   8.0
# 10     Кіровоградська  21.6  17.1  14.5  12.6   7.9  11.0  10.8   6.8
# 11          Луганська  26.2  23.5  14.4  11.6   6.2   9.6   5.1   NaN
# ...

# %% [markdown]
# Визначте типи всіх стовпців за допомогою dataframe.dtypes

# %%
birth_in_regions.dtypes
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990      float64
# 2000      float64
# 2012      float64
# 2014      float64
# 2019      float64
# dtype: object

# %% [markdown]
# Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

# %%
missing_percentages = birth_in_regions.isnull().sum() / len(birth_in_regions) * 100

print("Share missing:")
print(missing_percentages)
# Out:
# Share missing:
# Регіон     0.000000
# 1950       7.142857
# 1960       3.571429
# 1970       3.571429
# 1990       0.000000
# 2000       0.000000
# 2012       0.000000
# 2014       7.142857
# 2019      14.285714
# dtype: float64

# %% [markdown]
# Видаліть з таблиці дані по всій країні, останній рядок таблиці

# %%
birth_in_regions.drop([27], inplace=True)

birth_in_regions
# Out:
#                Регіон  1950  1960  1970  1990  2000  2012  2014  2019
# 0                Крим  23.0  20.6  16.0  13.0   7.3  12.6   NaN   NaN
# 1           Вінницька  22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# 2           Волинська  24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# 3    Дніпропетровська  20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# 4            Донецька  27.1  21.4  14.0  10.9   6.1   9.8   8.2   NaN
# 5         Житомирська  26.1  22.3  15.9  12.9   8.9  12.2  12.0   7.9
# 6        Закарпатська  31.4  27.3  20.7  16.8  11.5  15.1  14.6  10.4
# 7          Запорізька  21.9  19.7  15.0  12.4   7.1  10.6  10.6   6.8
# 8   Івано-Франківська  24.3  24.8  18.2  15.5  10.3  12.4  12.2   8.8
# 9            Київська  20.4  18.9  15.6  12.3   7.3  12.2  12.1   8.0
# 10     Кіровоградська  21.6  17.1  14.5  12.6   7.9  11.0  10.8   6.8
# 11          Луганська  26.2  23.5  14.4  11.6   6.2   9.6   5.1   NaN
# ...

# %% [markdown]
# Замініть відсутні дані в стовпцях середніми значеннями цих стовпців (метод fillna)

# %%
birth_in_regions.fillna(birth_in_regions.mean(numeric_only=True))

birth_in_regions
# Out:
#                Регіон    1950       1960  1970  1990  2000  2012    2014  \
# 0                Крим  23.000  20.600000  16.0  13.0   7.3  12.6  11.144
# 1           Вінницька  22.400  19.200000  14.2  12.4   8.4  11.2  10.900
# 2           Волинська  24.700  25.000000  17.9  15.3  11.2  14.8  14.100
# 3    Дніпропетровська  20.400  20.400000  15.1  12.3   7.1  11.2  11.100
# 4            Донецька  27.100  21.400000  14.0  10.9   6.1   9.8   8.200
# 5         Житомирська  26.100  22.300000  15.9  12.9   8.9  12.2  12.000
# 6        Закарпатська  31.400  27.300000  20.7  16.8  11.5  15.1  14.600
# 7          Запорізька  21.900  19.700000  15.0  12.4   7.1  10.6  10.600
# 8   Івано-Франківська  24.300  24.800000  18.2  15.5  10.3  12.4  12.200
# 9            Київська  20.400  18.900000  15.6  12.3   7.3  12.2  12.100
# 10     Кіровоградська  21.600  17.100000  14.5  12.6   7.9  11.0  10.800
# 11          Луганська  26.200  23.500000  14.4  11.6   6.2   9.6   5.100
# ...

# %% [markdown]
# Отримайте список регіонів, де рівень народжуваності у 2019 році був вищим за середній по Україні

# %%
above_average_regions = birth_in_regions[birth_in_regions['2019'] > birth_in_regions['2019'].mean()]
regions_list = above_average_regions['Регіон'].tolist()

print(regions_list)
# Out:
# ['Волинська', 'Закарпатська', 'Івано-Франківська', 'Львівська', 'Одеська', 'Рівненська', 'Херсонська', 'Чернівецька', 'Київ']

# %% [markdown]
# У якому регіоні була найвища народжуваність у 2014 році?

# %%
region_highest_birth_rate = birth_in_regions.loc[birth_in_regions['2014'].idxmax(), "Регіон"]

print(region_highest_birth_rate)
# Out:
# Рівненська

# %% [markdown]
# Побудуйте стовпчикову діаграму народжуваності по регіонах у 2019 році

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')

plt.figure(figsize=(10, 6))
plt.bar(birth_in_regions['Регіон'], birth_in_regions['2019'], color='skyblue')
plt.title('Рівень народжуваності у 2019 році за регіонами')
plt.xlabel('Регіон')
plt.ylabel('Рівень народжуваності (на 1000 осіб)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns


selected_regions = ['Волинська', 'Закарпатська', 'Івано-Франківська', 'Львівська', 'Одеська', 'Рівненська', 'Херсонська', 'Чернівецька', 'Київ']

selected_data = birth_in_regions[birth_in_regions['Регіон'].isin(selected_regions)]

fig, ax = plt.subplots(figsize=(12, 8))

for region in selected_regions:
    sns.lineplot(x=birth_in_regions.columns[1:], y=selected_data[selected_data['Регіон'] == region].iloc[0, 1:], marker='o', label=region)

plt.title('Рівень народжуваності протягом років для обраних регіонів')
plt.xlabel('Рік')
plt.ylabel('Рівень народжуваності')
plt.grid(linestyle='--')

plt.legend()

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
for col in birth_in_regions.columns[1:]:
    plt.bar(birth_in_regions['Регіон'], birth_in_regions[col].diff(), label=str(col))
plt.title('Зміна населення за роками')
plt.xlabel('Регіон')
plt.ylabel('Зміна населення')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.xticks(rotation=45, ha='right')
plt.show()
