# %% [markdown]
# <a href="https://colab.research.google.com/github/AleksandrRevuka/HW_Data_Science/blob/main/Hw2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_html("https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B8", attrs={"class": "wikitable"})

data
# Out:
# [        Unnamed: 0 січень 2021[i] Unnamed: 2 січень 2022[i]
#  0       Народжених         21 931          ▼         18 062
#  1         Померлих         57 721          ▼         57 248
#  2    Природний рух        -35 790          ▼        -39 186
#  3  Міграційний рух          2 272          ▲          2 282,
#     1960  1966  1970  1975  1980  1985  1990  1995  1997  2000  2002  2004  \
#  0   138   185   157   150   153   149   155   150   135   113    68    48
#
#     2006  2008  2010
#  0    38    43    36  ,
#       Рік Кількість народжень Коефіцієнт народжуваності Коефіцієнт фертильності
#  0   1860                   —                     ~50,0                       —
#  1   1896                   —                     ~47,5                       —
#  2   1906                   —                     ~44,0                       —
#  3   1913             ~1500,0                     ~40,0                   ~6,00
#  4   1925             ~1400,0                     ~38,0                     539
#  5   1940             ~1100,0                       273                       —
#  6   1950                8414                       228                     281
#  7   1955                7901                       200                       —
#  8   1960                8706                       205                     224
#  9   1965                6905                       153                       —
#  10  1970                7163                       152                     210
#  11  1975                7381                       151                       —
#  12  1980                7406                       148                     195
#  13  1985                7642                       150                       —
#  14  1990                6572                       127                     184
#  15  1995                4929                        96                     133
#  16  2000                3851                        78                     111
#  17  2005                4283                        90                     122
#  18  2010                4977                       152                     144
#  19  2015                4118                       107                     150
#  20  2020                2935                        78                     122,
#          Рік  1926  1939  1959  1970  1979  1989  2001  2013  2021
#  0  Чоловіки   484   477   444   452   456   462   463   462   464
#  1     Жінки   516   523   556   548   544   539   537   538   536,
#     1960  1965  1970  1975  1980  1985  1990  1992  1995  1997  2000  2003  \
#  0    12    17    29    34    36    36    37    43    38    37    40    37
#
#     2006  2009  2010[m]  2011[m]  2012[m]
#  0    38    32       27       40       37  ,
#     1990  1992  1994  1996  1998  2000  2002  2004  2006  2008  2010  2011  \
#  0   398   566   519   633   581   714   576   610   510   514   403   513
#
#     2012  2013
#  0   605   542  ,
#    Варіант прогнозу    2015    2020    2025    2030    2035    2040    2045  \
#  0          Високий  45 061  44 173  43 207  43 207  40 906  40 051  39 509
#  1         Середній  44 646  43 164  41 560  39 842  38 135  36 554  35 084
#  2          Низький  44 231  42 155  39 914  37 644  35 392  33 176  30 960
#
#       2050    2055    2060
#  0  39 137  38 793  38 463
#  1  33 658  32 244  30 859
#  2  28 731  26 528  24 388  ]

# %% [markdown]
# Вивести перші рядки таблиці за допомогою методу head

# %%
birth_table = pd.DataFrame(data[2])

print(birth_table.head())
# Out:
#     Рік Кількість народжень Коефіцієнт народжуваності Коефіцієнт фертильності
# 0  1860                   —                     ~50,0                       —
# 1  1896                   —                     ~47,5                       —
# 2  1906                   —                     ~44,0                       —
# 3  1913             ~1500,0                     ~40,0                   ~6,00
# 4  1925             ~1400,0                     ~38,0                     539

# %% [markdown]
# Визначте кількість рядків та стовпців у датафреймі (атрибут shape)

# %%
rows, colums = birth_table.shape

print(f"rows: {rows}\ncolums: {colums}")
# Out:
# rows: 21
# colums: 4

# %% [markdown]
# Замініть у таблиці значення "—" на значення NaN

# %%
import numpy as np


birth_table.replace("—", np.nan, inplace=True)

print(birth_table)
# Out:
#      Рік Кількість народжень Коефіцієнт народжуваності Коефіцієнт фертильності
# 0   1860                 NaN                     ~50,0                     NaN
# 1   1896                 NaN                     ~47,5                     NaN
# 2   1906                 NaN                     ~44,0                     NaN
# 3   1913             ~1500,0                     ~40,0                   ~6,00
# 4   1925             ~1400,0                     ~38,0                     539
# 5   1940             ~1100,0                       273                     NaN
# 6   1950                8414                       228                     281
# 7   1955                7901                       200                     NaN
# 8   1960                8706                       205                     224
# 9   1965                6905                       153                     NaN
# 10  1970                7163                       152                     210
# 11  1975                7381                       151                     NaN
# 12  1980                7406                       148                     195
# 13  1985                7642                       150                     NaN
# 14  1990                6572                       127                     184
# 15  1995                4929                        96                     133
# 16  2000                3851                        78                     111
# 17  2005                4283                        90                     122
# 18  2010                4977                       152                     144
# 19  2015                4118                       107                     150
# 20  2020                2935                        78                     122

# %% [markdown]
# Визначте типи всіх стовпців за допомогою dataframe.dtypes

# %%
birth_table.dtypes
# Out:
# Рік                           int64
# Кількість народжень          object
# Коефіцієнт народжуваності    object
# Коефіцієнт фертильності      object
# dtype: object

# %% [markdown]
# Замініть типи нечислових колонок на числові. Підказка - це колонки, де знаходився символ "—"

# %%
birth_table['Кількість народжень'] = pd.to_numeric(birth_table['Кількість народжень'], errors='coerce')
birth_table['Коефіцієнт народжуваності'] = pd.to_numeric(birth_table['Коефіцієнт народжуваності'], errors='coerce')
birth_table['Коефіцієнт фертильності'] = pd.to_numeric(birth_table['Коефіцієнт фертильності'], errors='coerce')

print(birth_table.dtypes)
# Out:
# Рік                            int64
# Кількість народжень          float64
# Коефіцієнт народжуваності    float64
# Коефіцієнт фертильності      float64
# dtype: object

# %% [markdown]
# Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

# %%
missing_percentages = birth_table.isnull().sum() / len(birth_table) * 100

print("Share missing:")
print(missing_percentages)
# Out:
# Share missing:
# Рік                           0.000000
# Кількість народжень          14.285714
# Коефіцієнт народжуваності     0.000000
# Коефіцієнт фертильності      38.095238
# dtype: float64

# %% [markdown]
# Видаліть з таблиці дані по всій країні, останній рядок таблиці

# %%
birth_table.drop([20], inplace=True)

birth_table
# Out:
#      Рік  Кількість народжень  Коефіцієнт народжуваності  \
# 0   1860                  NaN                        500
# 1   1896                  NaN                        475
# 2   1906                  NaN                        440
# 3   1913              15000.0                        400
# 4   1925              14000.0                        380
# 5   1940              11000.0                        273
# 6   1950               8414.0                        228
# 7   1955               7901.0                        200
# 8   1960               8706.0                        205
# 9   1965               6905.0                        153
# 10  1970               7163.0                        152
# 11  1975               7381.0                        151
# 12  1980               7406.0                        148
# 13  1985               7642.0                        150
# 14  1990               6572.0                        127
# 15  1995               4929.0                         96
# 16  2000               3851.0                         78
# 17  2005               4283.0                         90
# 18  2010               4977.0                        152
# 19  2015               4118.0                        107
#
#     Коефіцієнт фертильності
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                     600.0
# 4                     539.0
# 5                       NaN
# 6                     281.0
# 7                       NaN
# 8                     224.0
# 9                       NaN
# 10                    210.0
# 11                      NaN
# 12                    195.0
# 13                      NaN
# 14                    184.0
# 15                    133.0
# 16                    111.0
# 17                    122.0
# 18                    144.0
# 19                    150.0

# %% [markdown]
# Замініть відсутні дані в стовпцях середніми значеннями цих стовпців (метод fillna)

# %%
birth_table.fillna(birth_table.mean(), inplace=True)

birth_table
# Out:
#      Рік  Кількість народжень  Коефіцієнт народжуваності  \
# 0   1860          7661.647059                        500
# 1   1896          7661.647059                        475
# 2   1906          7661.647059                        440
# 3   1913         15000.000000                        400
# 4   1925         14000.000000                        380
# 5   1940         11000.000000                        273
# 6   1950          8414.000000                        228
# 7   1955          7901.000000                        200
# 8   1960          8706.000000                        205
# 9   1965          6905.000000                        153
# 10  1970          7163.000000                        152
# 11  1975          7381.000000                        151
# 12  1980          7406.000000                        148
# 13  1985          7642.000000                        150
# 14  1990          6572.000000                        127
# 15  1995          4929.000000                         96
# 16  2000          3851.000000                         78
# 17  2005          4283.000000                         90
# 18  2010          4977.000000                        152
# 19  2015          4118.000000                        107
#
#     Коефіцієнт фертильності
# 0                241.083333
# 1                241.083333
# 2                241.083333
# 3                600.000000
# 4                539.000000
# 5                241.083333
# 6                281.000000
# 7                241.083333
# 8                224.000000
# 9                241.083333
# 10               210.000000
# 11               241.083333
# 12               195.000000
# 13               241.083333
# 14               184.000000
# 15               133.000000
# 16               111.000000
# 17               122.000000
# 18               144.000000
# 19               150.000000

# %% [markdown]
# Отримайте список регіонів, де рівень народжуваності у 2019 році був вищим за середній по Україні

# %%
import pandas as pd

data = pd.read_html("https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B8", attrs={"class": "wikitable collapsible collapsed"})
birth_in_regions = data[3]

for col in birth_in_regions.columns[1:]:
    birth_in_regions[col] = pd.to_numeric(birth_in_regions[col], errors='coerce') * 0.1

birth_in_regions.drop([27], inplace=True)

above_average_regions = birth_in_regions[birth_in_regions['2019'] > birth_in_regions['2019'].mean()]
regions_list = above_average_regions['Регіон'].tolist()

print(birth_in_regions, "\n")

print(regions_list)
# Out:
#                Регіон  1950  1960  1970  1990  2000  2012  2014  2019
# 0                Крим  23.0  20.6  16.0  13.0   7.3  12.6   NaN   NaN
# 1           Вінницька  22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# 2           Волинська  24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# 3    Дніпропетровська  20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# 4            Донецька  27.1  21.4  14.0  10.9   6.1   9.8   8.2   NaN
# 5         Житомирська  26.1  22.3  15.9  12.9   8.9  12.2  12.0   7.9
# 6        Закарпатська  31.4  27.3  20.7  16.8  11.5  15.1  14.6  10.4
# 7          Запорізька  21.9  19.7  15.0  12.4   7.1  10.6  10.6   6.8
# 8   Івано-Франківська  24.3  24.8  18.2  15.5  10.3  12.4  12.2   8.8
# 9            Київська  20.4  18.9  15.6  12.3   7.3  12.2  12.1   8.0
# 10     Кіровоградська  21.6  17.1  14.5  12.6   7.9  11.0  10.8   6.8
# 11          Луганська  26.2  23.5  14.4  11.6   6.2   9.6   5.1   NaN
# 12          Львівська  23.4  24.0  17.1  14.0   9.1  11.9  11.9   8.7
# 13       Миколаївська  21.1  19.4  15.5  13.7   8.0  11.5  11.2   7.1
# 14            Одеська  24.1  19.2  14.8  12.6   8.0  12.7  12.3   8.8
# 15         Полтавська  18.6  16.3  13.1  11.8   7.0   9.9  10.0   6.5
# 16         Рівненська  26.9  26.7  19.3  15.8  11.8  15.9  14.8  10.7
# 17            Сумська  21.6  18.4  13.2  11.5   7.0   9.7   9.2   6.0
# 18      Тернопільська  21.3  21.6  15.7  14.2   9.2  11.3  10.9   7.6
# 19         Харківська  19.7  17.3  14.0  11.4   6.8   9.9  10.1   6.8
# 20         Херсонська  20.8  21.4  16.6  14.3   8.5  11.7  11.5   8.1
# 21        Хмельницька  23.4  19.8  14.8  12.9   8.5  11.3  11.2   7.9
# 22          Черкаська  20.5  17.9  14.4  12.3   7.5  10.0   9.8   6.4
# 23        Чернівецька  24.7  21.8  17.0  14.8  10.1  12.8  12.9   9.2
# 24       Чернігівська  22.0  18.3  12.7  10.8   6.9   9.4   9.0   6.1
# 25               Київ   NaN  17.4  15.9  12.0   7.3  12.0  12.1  11.0
# 26        Севастополь   NaN   NaN   NaN  12.5   7.0  12.0   NaN   NaN
#
# ['Волинська', 'Закарпатська', 'Івано-Франківська', 'Львівська', 'Одеська', 'Рівненська', 'Херсонська', 'Чернівецька', 'Київ']

# %% [markdown]
# У якому регіоні була найвища народжуваність у 2014 році?

# %%
region_highest_birth_rate = birth_in_regions.loc[birth_in_regions['2014'].idxmax(), "Регіон"]

print(region_highest_birth_rate)
# Out:
# Рівненська

# %% [markdown]
# Побудуйте стовпчикову діаграму народжуваності по регіонах у 2019 році

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(20, 8))

birth_in_regions.set_index("Регіон", inplace=True)
plt.xlabel("Регіон")
plt.ylabel("Народжуваність")

birth_in_regions.plot(kind="bar", ax=ax)

plt.xticks(rotation=45)
plt.grid(linestyle='--', axis='y')

plt.show()
