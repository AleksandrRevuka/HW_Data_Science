# %% [markdown]
# <a href="https://colab.research.google.com/github/AleksandrRevuka/HW_Data_Science/blob/main/Hw2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-3af77a90-046f-4e22-94e8-ca6d7d5379e0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3af77a90-046f-4e22-94e8-ca6d7d5379e0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ***Прочитайте файл 2017_jun_final.csv за допомогою методу read_csv***

# %%
import pandas as pd

data = pd.read_csv("2017_jun_final.csv")

data
# Out:
#          N                 Должность Язык.программирования Специализация  \
# 0        1        Junior QA engineer                   NaN     Manual QA
# 1        2        Junior QA engineer                   NaN     Manual QA
# 2        3         Software Engineer               C#/.NET           NaN
# 3        4         Software Engineer            JavaScript           NaN
# 4        5  Senior Software Engineer            JavaScript           NaN
# ...    ...                       ...                   ...           ...
# 8699  8700               QA engineer                   NaN     Manual QA
# 8700  8701                 Marketing                   NaN           NaN
# 8701  8702  Junior Software Engineer            Ruby/Rails           NaN
# 8702  8703                 Team lead                   NaN           NaN
# 8703  8704  Senior Software Engineer                  Java           NaN
#
#      Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# ...

# %% [markdown]
# ***Прочитайте отриману таблицю, використовуючи метод head***

# %%
developer_survey_results = pd.DataFrame(data)

developer_survey_results.head()
# Out:
#    N                 Должность Язык.программирования Специализация  \
# 0  1        Junior QA engineer                   NaN     Manual QA
# 1  2        Junior QA engineer                   NaN     Manual QA
# 2  3         Software Engineer               C#/.NET           NaN
# 3  4         Software Engineer            JavaScript           NaN
# 4  5  Senior Software Engineer            JavaScript           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
# 3                 5                            4              2000
# 4    10 и более лет                          0.5              4500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                 0  Харьков       до 10 человек  ...
# ...

# %% [markdown]
# ***Визначте розмір таблиці за допомогою методу shape***

# %%
rows, colums = developer_survey_results.shape

print(f"rows: {rows}\ncolums: {colums}")
# Out:
# rows: 8704
# colums: 25

# %% [markdown]
# ***Визначте типи всіх стовпців за допомогою dataframe.dtypes***

# %%
developer_survey_results.dtypes
# Out:
# N                                     int64
# Должность                            object
# Язык.программирования                object
# Специализация                        object
# Общий.опыт.работы                    object
# Опыт.работы.на.текущем.месте         object
# Зарплата.в.месяц                      int64
# Изменение.зарплаты.за.12.месяцев      int64
# Город                                object
# Размер.компании                      object
# Тип.компании                         object
# Пол                                  object
# Возраст                               int64
# Образование                          object
# Университет                          object
# Еще.студент                            bool
# Уровень.английского                  object
# Предметная.область                   object
# Дата.заполнения                      object
# User.Agent                           object
# exp                                 float64
# ...

# %% [markdown]
# ***Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)***

# %%
missing_percentages = developer_survey_results.isnull().sum() / len(developer_survey_results) * 100

print("Share missing:")
print(missing_percentages)
# Out:
# Share missing:
# N                                    0.000000
# Должность                            0.000000
# Язык.программирования               44.232537
# Специализация                       82.938879
# Общий.опыт.работы                    0.000000
# Опыт.работы.на.текущем.месте         0.000000
# Зарплата.в.месяц                     0.000000
# Изменение.зарплаты.за.12.месяцев     0.000000
# Город                                0.000000
# Размер.компании                      0.000000
# Тип.компании                         0.000000
# Пол                                  0.000000
# Возраст                              0.000000
# Образование                          0.000000
# Университет                          4.113051
# Еще.студент                          0.000000
# Уровень.английского                  0.000000
# Предметная.область                   2.562040
# Дата.заполнения                      0.000000
# User.Agent                           0.000000
# ...

# %% [markdown]
# ***Видаліть усі стовпці з пропусками, крім стовпця "Мова програмування"***
#
# ***Знову порахуйте, яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився тільки стовпець "Мова.програмування" ***

# %%
data_cleaned = developer_survey_results.dropna(axis=0, subset=developer_survey_results.columns.difference(['Язык.программирования']))

missing_percentages = data_cleaned.isnull().sum() / len(data_cleaned) * 100

print("Share missing:")
print(missing_percentages)
# Out:
# Share missing:
# N                                     0.0
# Должность                             0.0
# Язык.программирования               100.0
# Специализация                         0.0
# Общий.опыт.работы                     0.0
# Опыт.работы.на.текущем.месте          0.0
# Зарплата.в.месяц                      0.0
# Изменение.зарплаты.за.12.месяцев      0.0
# Город                                 0.0
# Размер.компании                       0.0
# Тип.компании                          0.0
# Пол                                   0.0
# Возраст                               0.0
# Образование                           0.0
# Университет                           0.0
# Еще.студент                           0.0
# Уровень.английского                   0.0
# Предметная.область                    0.0
# Дата.заполнения                       0.0
# User.Agent                            0.0
# exp                                   0.0
# current_job_exp                       0.0
# ...

# %% [markdown]
# ***Видаліть усі рядки у вихідній таблиці за допомогою методу dropna***

# %%
data_cleaned = developer_survey_results.dropna()

data_cleaned
# Out:
# Empty DataFrame
# Columns: [N, Должность, Язык.программирования, Специализация, Общий.опыт.работы, Опыт.работы.на.текущем.месте, Зарплата.в.месяц, Изменение.зарплаты.за.12.месяцев, Город, Размер.компании, Тип.компании, Пол, Возраст, Образование, Университет, Еще.студент, Уровень.английского, Предметная.область, Дата.заполнения, User.Agent, exp, current_job_exp, salary, Валюта, cls]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# ***Визначте новий розмір таблиці за допомогою методу shape***

# %%
rows, colums = data_cleaned.shape

print(f"rows: {rows}\ncolums: {colums}")
# Out:
# rows: 0
# colums: 25

# %% [markdown]
# ***Створіть нову таблицю python_data, в якій будуть тільки рядки зі спеціалістами, які вказали мову програмування Python***

# %%
developer_python = developer_survey_results[developer_survey_results['Язык.программирования'] == "Python"]

developer_python
# Out:
#          N                 Должность Язык.программирования Специализация  \
# 12      13         Software Engineer                Python           NaN
# 68      69         Software Engineer                Python           NaN
# 87      88  Junior Software Engineer                Python           NaN
# 114    115  Junior Software Engineer                Python           NaN
# 143    144  Junior Software Engineer                Python           NaN
# ...    ...                       ...                   ...           ...
# 8546  8547         Software Engineer                Python           NaN
# 8625  8626         Software Engineer                Python           NaN
# 8635  8636  Senior Software Engineer                Python           NaN
# 8673  8674  Junior Software Engineer                Python           NaN
# 8695  8696         Software Engineer                Python           NaN
#
#      Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# ...

# %% [markdown]
# ***Визначте розмір таблиці python_data за допомогою методу shape***

# %%
rows, colums = developer_python.shape

print(f"rows: {rows}\ncolums: {colums}")
# Out:
# rows: 207
# colums: 25

# %% [markdown]
# ***Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"***

# %%
groupby_position = developer_survey_results.groupby("Должность")

for position, group in groupby_position:
    print(f"Група '{position}':")
# Out:
# Група 'Business analyst':
# Група 'DBA':
# Група 'Data Scientist / Data Analyst':
# Група 'Designer':
# Група 'DevOps':
# Група 'Director of Engineering / Program Director':
# Група 'ERP / CRM':
# Група 'Game designer':
# Група 'HR':
# Група 'HTML coder':
# Група 'Junior QA engineer':
# Група 'Junior Software Engineer':
# Група 'Marketing':
# Група 'Product Manager':
# Група 'Project manager':
# Група 'QA Tech Lead':
# Група 'QA engineer':
# Група 'Research Engineer':
# Група 'Sales manager':
# Група 'Scrum Master':
# Група 'Security Specialist':
# Група 'Senior Project Manager / Program Manager':
# Група 'Senior QA engineer':
# Група 'Senior Software Engineer':
# Група 'Software Engineer':
# Група 'Support':
# Група 'Sysadmin':
# Група 'System Architect':
# Група 'Talent Researcher':
# Група 'Team lead':
# Група 'Technical Lead':
# Група 'Technical writer':

# %% [markdown]
# ***Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада", виконайте агрегацію даних за допомогою методу agg і знайдіть мінімальне та максимальне значення у стовпчику "Зарплата.в.місяць"***

# %%
aggregated_data = groupby_position.agg({"Зарплата.в.месяц": ["min", "max"]})

print(aggregated_data)
# Out:
#                                            Зарплата.в.месяц
#                                                         min    max
# Должность
# Business analyst                                        200   5000
# DBA                                                     380   6000
# Data Scientist / Data Analyst                           150   8000
# Designer                                                100   4000
# DevOps                                                  194  10000
# Director of Engineering / Program Director             1500  34000
# ERP / CRM                                               100   6000
# Game designer                                           150   6800
# HR                                                      100   7000
# HTML coder                                              154   3000
# Junior QA engineer                                       96   2000
# Junior Software Engineer                                 75   2600
# ...

# %% [markdown]
# ***Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць. Використовуйте її для методу apply та створіть новий стовпчик "avg"***

# %%
def fill_avg_salary(row):
    return row["Зарплата.в.месяц"].mean()

aggregated_data["avg"] = aggregated_data.apply(lambda row: fill_avg_salary(row), axis=1)

print(aggregated_data)
# Out:
#                                            Зарплата.в.месяц             avg
#                                                         min    max
# Должность
# Business analyst                                        200   5000   2600.0
# DBA                                                     380   6000   3190.0
# Data Scientist / Data Analyst                           150   8000   4075.0
# Designer                                                100   4000   2050.0
# DevOps                                                  194  10000   5097.0
# Director of Engineering / Program Director             1500  34000  17750.0
# ERP / CRM                                               100   6000   3050.0
# Game designer                                           150   6800   3475.0
# HR                                                      100   7000   3550.0
# HTML coder                                              154   3000   1577.0
# ...

# %% [markdown]
# ***Створіть описову статистику за допомогою методу describe для нового стовпчика.***

# %%
statistics = aggregated_data.describe()
print(statistics)
# Out:
#       Зарплата.в.месяц                       avg
#                    min         max
# count        32.000000     32.0000     32.000000
# mean        250.031250   6648.4375   3449.234375
# std         258.096817   5957.2602   3093.885174
# min          75.000000   1700.0000    900.000000
# 25%         100.000000   3487.5000   1820.500000
# 50%         172.000000   5500.0000   2837.500000
# 75%         312.500000   7250.0000   3756.250000
# max        1500.000000  34000.0000  17750.000000

# %% [markdown]
# ***Збережіть отриману таблицю в CSV файл***

# %%
aggregated_data.to_csv("salary_per_month.csv", index=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.barplot(x="Город", y="salary", data=developer_survey_results, errorbar=None, palette="viridis")
plt.title('Середня Зарплата за Містами')
plt.xlabel('Місто')
plt.ylabel('Середня Зарплата')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(developer_survey_results['salary'], bins=30, kde=True, color='skyblue')
plt.title('Розподіл Зарплат')
plt.xlabel('Зарплата')
plt.ylabel('Частота')
plt.show()

# %%
plt.figure(figsize=(8, 8))
developer_survey_results['Уровень.английского'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=['lightcoral', 'lightgreen', 'lightblue'])
plt.title('Розподіл Рівнів Знання Англійської')
plt.ylabel('')
plt.show()
